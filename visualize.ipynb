# %%
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd
import requests

# %%
img = Image.open(requests.get('https://ultralytics.com/images/bus.jpg', stream=True).raw)
centers = pd.read_csv('/Users/abdu/Downloads/bus.csv')

plt.imshow(img)
plt.scatter(centers['x'], centers['y'], c='r', s=10)
plt.show()
